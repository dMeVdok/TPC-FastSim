# %%
import tensorflow as tf
from nn import MomentsToImage, ImageToMoments

from data import preprocessing
from tqdm import tqdm

preprocessing._VERSION = 'data_v4'
data, features = preprocessing.read_csv_2d(pad_range=[-3,5], time_range=[-7,9])
features = features.astype('float32')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# /var/folders/2_/b_blzgjx3dj8pq_qwftwcn9c0000gn/T/ipykernel_7827/2687503629.py in <module>
#       2 from nn import MomentsToImage, ImageToMoments
#       3
# ----> 4 from ..data import preprocessing
#       5 from tqdm import tqdm
#       6
#
# ImportError: attempted relative import with no known parent package

# %%
model = tf.keras.models.load_model(
    "../saved_models/feb9/generator_05000.h5",
    custom_objects={
        'MomentsToImage': MomentsToImage(), 
        'ImageToMoments': ImageToMoments()
    },
    compile=True
)

# %%
tf.keras.utils.plot_model(model, show_shapes=True, expand_nested=True)

# %%
import matplotlib.pyplot as plt

plt.imshow(model(tf.random.uniform(shape=(1,37), minval=-5, maxval=5))[0])
plt.colorbar()

# %%
# Out:
# <tf.Tensor: shape=(), dtype=float32, numpy=9.998868>
